# %%
import re
import gensim

import xml.etree.ElementTree as et

# %%
xtree = et.parse("bloggmix2001.xml")
xroot = xtree.getroot()

# %%
for node in xroot:
    print(node.attrib)
# Out:
# {'url': 'http://typicalday.blogg.se/', 'title': 'Tatiana Rojas', 'age': '', 'city': 'Västerås', 'categories': '|Foto och konst > Allmänt och övrigt|Foto och konst > Fotografer|Mode och design > Inredningsdesign|Mode och design > Mode, allmänt|Mode och design > Mode, kvinnor|Mode och design > Prylar|Resor > På resande fot|'}
# {'url': 'http://niiisan.myshowroom.se/', 'title': 'Niiisan', 'age': '', 'city': 'Göteborg', 'categories': '|Mode och design > Mode, kvinnor|Sex, skvaller och dejting > Aktuella evenemang|'}
# {'url': 'http://badlandshyena.wordpress.com/', 'title': 'Badlands Hyena', 'age': '', 'city': '', 'categories': '|Humor > Allmänt och övrigt|Humor > Satir|Journalister och media > Allmänt och övrigt|Politik och samhälle > Allmänt och övrigt|Politik och samhälle > Allmänt, höger|Politik och samhälle > Partioberoende|Politik och samhälle > Tankesmedjor|'}
# ...
